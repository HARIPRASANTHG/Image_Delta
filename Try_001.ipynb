# %%
# %matplotlib inline

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread("./f1_samp.png", cv.IMREAD_COLOR)
#img = img[...,::-1]
img.shape
# Out:
# (275, 980, 3)

# %%
plt.hist(img.ravel(), bins=range(256), fc='k', ec='k')
# Out:
# (array([2.38350e+04, 1.57540e+04, 6.09900e+03, 7.09100e+03, 6.30000e+03,
#         4.36300e+03, 4.38000e+02, 2.74600e+03, 5.84000e+02, 9.58000e+02,
#         2.12000e+02, 7.95000e+02, 2.32000e+02, 1.10000e+01, 5.07000e+02,
#         2.64000e+02, 0.00000e+00, 0.00000e+00, 2.96000e+02, 0.00000e+00,
#         1.20400e+03, 8.31000e+02, 0.00000e+00, 1.77000e+02, 5.41000e+02,
#         2.13000e+02, 7.26000e+02, 0.00000e+00, 0.00000e+00, 4.19000e+02,
#         1.10600e+03, 2.73000e+02, 1.93000e+02, 3.74000e+02, 5.81000e+02,
#         1.32400e+03, 5.69000e+02, 0.00000e+00, 0.00000e+00, 5.46000e+02,
#         3.70000e+01, 5.24000e+02, 7.47000e+02, 9.52000e+02, 8.13000e+02,
#         7.06000e+02, 4.12000e+02, 3.24000e+02, 1.04700e+03, 5.63000e+02,
#         7.22000e+02, 0.00000e+00, 1.25500e+03, 2.08000e+02, 3.11000e+02,
#         9.22000e+02, 2.14000e+02, 0.00000e+00, 2.93000e+02, 1.42400e+03,
#         5.24000e+02, 8.34000e+02, 1.31200e+03, 9.65000e+02, 9.46000e+02,
# ...

# %%
imgplot = plt.imshow(img[0:275,6:485])

# %%
cv.imwrite("aero_f1_left.png", cv.cvtColor(img[:,6:485], cv.COLOR_RGB2BGR))
cv.imwrite("aero_f1_right.png", cv.cvtColor(img[:,495:974], cv.COLOR_RGB2BGR))
# Out:
# True

# %%
# Importing Image class from PIL module
from PIL import Image

# Opens a image in RGB mode
im = Image.open("./f1_samp.png")

# Size of the image in pixels (size of original image)
# (This is not mandatory)
width, height = im.size

# Setting the points for cropped image
left = 5
top = height / 4
right = 164
bottom = 3 * height / 4

# Cropped image of above dimension
# (It will not change original image)
im1 = im.crop((6, 272, 485, 2))

# Shows the image in image viewer
im.show()
# Out:
# (eog:12232): Gtk-WARNING **: 17:29:00.220: Theme parsing error: gtk.css:2:121: Failed to import: Error opening file /home/hari/.local/share/gnome-shell/extensions/unite@hardpixel.eu/styles/gtk3/buttons-right/maximized.css: No such file or directory
#
# (eog:12232): Gtk-WARNING **: 17:29:00.220: Theme parsing error: gtk.css:5:121: Failed to import: Error opening file /home/hari/.local/share/gnome-shell/extensions/unite@hardpixel.eu/styles/gtk3/buttons-right/maximized.css: No such file or directory
